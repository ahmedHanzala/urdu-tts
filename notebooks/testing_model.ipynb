# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedHanzala/urdu-voice-cloning/blob/main/notebooks/testing_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/152334H/tortoise-tts-fast
# %cd tortoise-tts-fast
# !pip3 install -r requirements.txt --no-deps
# !pip3 install -e .
# !pip3 install git+https://github.com/152334H/BigVGAN.git

# %%
#@title # Setup
# Imports used through the rest of the notebook.
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F

import IPython

from tortoise.api import TextToSpeech
from tortoise.utils.audio import load_audio, load_voice, load_voices

# This will download all the models used by Tortoise from the HuggingFace hub.
tts = TextToSpeech()

# %%
# %cd ..
# !ls
# Out:
# /content
# drive  sample_data  tortoise-tts-fast

# %% [markdown]
# <h1>Base Model for comparison</h1>

# %%
text= "We are testing this model for our project"
gen = tts.tts_with_preset(text, voice_samples=None, conditioning_latents=None, preset="fast")
torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('generated.wav')
# Out:
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:12<00:00,  2.06s/it]
# Computing best candidates using CLVP
# 100%|██████████| 6/6 [00:02<00:00,  2.75it/s]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 20/20 [00:01<00:00, 13.77it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1> Model Trained on South Asian Accent

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !python tortoise-tts-fast/scripts/tortoise_tts.py -o hello.wav "We are testing this model for our project" -v daniel --preset high_quality --ar_checkpoint drive/MyDrive/trainer/models/south-asian-accent/1827_gpt.pth

# %%
import IPython
IPython.display.Audio(filename='results/daniel_00_00.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1>Urdu Language Testing on Base Model</h1>

# %%
text= "seecs ایک بہت اچھا ڈیپارٹمنٹ ہے"
gen = tts.tts_with_preset(text, voice_samples=None, conditioning_latents=None, preset="fast")
torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('generated.wav')
# Out:
# ...
# Done.
# ...
# Done.
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:33<00:00,  5.57s/it]
# Computing best candidates using CLVP
# 100%|██████████| 6/6 [00:02<00:00,  2.68it/s]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 20/20 [00:02<00:00,  9.68it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1>Urdu Language Testing on Our Model</h1>

# %%
# !python tortoise-tts-fast/scripts/tortoise_tts.py -o hello.wav "seecs ایک بہت اچھا ڈیپارٹمنٹ ہے" -v daniel --preset high_quality --ar_checkpoint drive/MyDrive/trainer/models/urdu-model/1800_gpt.pth
import IPython
IPython.display.Audio(filename='results/daniel_00_00.wav')
# Out:
# Loading tts...
# Removing weight norm...
# Rendering daniel_00 (1 of 1)...
#   seecs ایک بہت اچھا ڈیپارٹمنٹ ہے
# mode 0
# Generating autoregressive samples..
# 100% 16/16 [02:17<00:00,  8.59s/it]
# Computing best candidates using CLVP
# 100% 16/16 [00:13<00:00,  1.17it/s]
# Transforming autoregressive outputs into audio..
# 100% 400/400 [00:29<00:00, 13.65it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1>Junaid Akram Voice Cloning on base model</h1>

# %%
voice = 'junaid'
preset='fast'
text= "seecs ایک بہت اچھا ڈیپارٹمنٹ ہے"
# Load it and send it through Tortoise.

voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents,
                          preset=preset)
torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('generated.wav')
# Out:
# mode 0
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:22<00:00,  3.77s/it]
# Computing best candidates using CLVP
# 100%|██████████| 6/6 [00:02<00:00,  2.92it/s]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 20/20 [00:01<00:00, 10.85it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1>Junaid Akram Voice Cloning on Our Model</h1>

# %%
# !python tortoise-tts-fast/scripts/tortoise_tts.py -o hello.wav "آپ کہاں سے ہیں؟" -v daniel --preset high_quality --ar_checkpoint drive/MyDrive/trainer/models/junaid-akram-finetuned/1800_gpt.pth
import IPython
IPython.display.Audio(filename='results/daniel_00_00.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1>wave-to-video</h1>

# %%
# !cd gdrive/MyDrive/Wav2LipBase && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/gdrive/MyDrive/Wav2Lip/imrankhan.mp4" --audio "/content/gdrive/MyDrive/Wav2Lip/test.wav"

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/drive/MyDrive/Wav2LipBase/results/result_voice.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
